# %%
# !pip install torch==1.7.1+cu110 torchvision==0.8.2+cu110 torchaudio==0.7.2 -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# ...
#      |███████████████████████         | 834.1 MB 1.2 MB/s eta 0:04:19tcmalloc: large alloc 1147494400 bytes == 0x3a288000 @  0x7ffb1c1c6615 0x5d631c 0x51e4f1 0x51e67b 0x4f7585 0x49ca7c 0x4fdff5 0x49caa1 0x4fdff5 0x49ced5 0x4f60a9 0x55f926 0x4f60a9 0x55f926 0x4f60a9 0x55f926 0x5d7c18 0x5d9412 0x586636 0x5d813c 0x55f3fd 0x55e571 0x5d7cf1 0x49ced5 0x55e571 0x5d7cf1 0x49ec69 0x5d7c18 0x49ca7c 0x4fdff5 0x49ced5
#      |█████████████████████████████▏  | 1055.7 MB 1.2 MB/s eta 0:01:27tcmalloc: large alloc 1434370048 bytes == 0x7e8de000 @  0x7ffb1c1c6615 0x5d631c 0x51e4f1 0x51e67b 0x4f7585 0x49ca7c 0x4fdff5 0x49caa1 0x4fdff5 0x49ced5 0x4f60a9 0x55f926 0x4f60a9 0x55f926 0x4f60a9 0x55f926 0x5d7c18 0x5d9412 0x586636 0x5d813c 0x55f3fd 0x55e571 0x5d7cf1 0x49ced5 0x55e571 0x5d7cf1 0x49ec69 0x5d7c18 0x49ca7c 0x4fdff5 0x49ced5
# ...

# %%
# !pip install -r /content/drive/MyDrive/Scene_Segmentation/docs/requirements.txt
# !pip install pytube3 --upgrade
# !python -m pip install --upgrade pytube
# !apt install ffmpeg
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 593 kB 31.1 MB/s
# ...
#      |████████████████████████████████| 190 kB 58.2 MB/s
# ...
#   Created wheel for mmcv: filename=mmcv-1.7.0-py2.py3-none-any.whl size=914087 sha256=3cb01016fc95b92c7b6d4e9a1190ea9f793d039a4379acf5243d1dac0cf6d4b6
#   Stored in directory: /root/.cache/pip/wheels/9b/89/2b/4dd481113713f57069c98473061037314d4f80a66077a3b5ec
# Successfully built mmcv
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 56 kB 395 kB/s
# ...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# ffmpeg is already the newest version (7:3.4.11-0ubuntu0.1).
# ...

# %%
# !pip install tensorboardX
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 125 kB 34.4 MB/s
# ...

# %%
cd /content/drive/MyDrive/Scene_Segmentation
# Out:
# /content/drive/MyDrive/Scene_Segmentation

# %%
# !python segment_scenes.py --url=https://www.youtube.com/watch?v=TyRVyo5zSYU --config=lgss/config/inference.py --threshold=0.7
# Out:
# /usr/local/lib/python3.8/dist-packages/mmcv/__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(
# ...
# Video ID: TyRVyo5zSYU
# YouTube video downloaded!
#
# Running Shot Detection ...
# 100% 4066/4066 [00:11<00:00, 361.15frames/s]
# List of shots obtained:
# Shot    0: Start 00:00:00.000 / Frame 0, End 00:00:00.967 / Frame 29
# Shot    1: Start 00:00:00.967 / Frame 29, End 00:00:08.067 / Frame 242
# Shot    2: Start 00:00:08.067 / Frame 242, End 00:00:10.967 / Frame 329
# Shot    3: Start 00:00:10.967 / Frame 329, End 00:00:15.933 / Frame 478
# Shot    4: Start 00:00:15.933 / Frame 478, End 00:00:18.067 / Frame 542
# ...
